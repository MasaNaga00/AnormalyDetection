# %% [markdown]
# - state_logic.py … 閾値検出（既存）
# - state_logic_cusum.py … CUSUM（裏で継続検討する用）
# - signal_b_peer.py … 信号B（SF群内ピア比較）
# - signal_c_dist.py … 信号C（販社別の月次急増）
# - unified_inbox.py … 3検出器の統合
# - run_month.py … 月次実行スクリプト

# %% [markdown]
# # 初回実行

# %%
# %run run_month.py panel_初回.csv 台帳_空.xlsx
# Out:
# パネル: 22285行  ALL=3925  販社別=18360
# 台帳: 0行
# /Users/nagaomasashi/Documents/Python/claude/AnormalyDetection/閾値判定2/signal_b_peer.py:152: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   on=["biz", "sf", "dev"], how="left")["_x"].fillna(False)
# === 判定年月 202412 ／ 発火 8件（上位15件をレビュー）===
# 検出器
# 閾値        3
# 閾値/信号B    2
# 信号C       2
# 信号B       1
#
# 開発コード    部番    検出器 対象販社  統合注目度                                                             指標
#   M02 101-0 閾値/信号B  ALL  3.500 累積率11.60% / 閾値5.00% ｜ SF=SF-101 O/E=4.25 (ピア8機種, nb=1, 部番691件)
#   M06 102-0 閾値/信号B  ALL  3.500  累積率7.49% / 閾値5.00% ｜ SF=SF-102 O/E=2.48 (ピア8機種, nb=1, 部番490件)
#   M01 100-0    信号C    C  3.000                                       O/E=7.53 使用16件 p=3.9e-08
# ...

# %% [markdown]
# - レビュー用_YYYYMM.csv の事業コードから判定年月のカラムまでの値を「台帳.xlsx」に貼り付ける
#
# 必ず埋める
# - 処置区分 … 下の8択から
# - 記録日 … 記入した日
# - 確認者 … 自分の名前
#
# 必要なときだけ埋める
# - 再評価年月 … 空欄なら検出器ごとの既定期間が自動で効く（下表）
# - 上書き閾値 … 「新常態受容」のときの新しい基準X（%）
# - 原因メモ … 後から見て分かるように

# %% [markdown]
# # 2回目実行

# %%
# %run run_month.py panel_翌月.csv 台帳_記入例.xlsx
# Out:
# パネル: 22885行  ALL=4025  販社別=18860
# 台帳: 8行
# /Users/nagaomasashi/Documents/Python/claude/AnormalyDetection/閾値判定2/signal_b_peer.py:152: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   on=["biz", "sf", "dev"], how="left")["_x"].fillna(False)
# === 判定年月 202501 ／ 発火 4件（上位15件をレビュー）===
# 検出器
# 信号C       3
# 閾値/信号B    1
#
# 開発コード    部番    検出器 対象販社  統合注目度                                                            指標
#   M06 102-0 閾値/信号B  ALL  3.500 累積率7.60% / 閾値5.00% ｜ SF=SF-102 O/E=2.52 (ピア9機種, nb=1, 部番490件)
#   M10 103-0    信号C    A  3.000                                     O/E=15.88 使用21件 p=3.2e-14
#   M10 103-1    信号C    A  3.000                                     O/E=12.86 使用17件 p=6.6e-11
# ...
